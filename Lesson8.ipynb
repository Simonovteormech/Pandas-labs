# %% [markdown]
# 1) В этой задаче выведите информацию о датасете, используя функцию .info()

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Leher\Downloads\disney_title.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          1450 non-null   object
#  1   title         1450 non-null   object
#  2   director      977 non-null    object
#  3   cast          1260 non-null   object
#  4   country       1231 non-null   object
#  5   release_year  1450 non-null   int64
#  6   rating        1447 non-null   object
#  7   duration      1450 non-null   object
#  8   listed_in     1450 non-null   object
#  9   description   1450 non-null   object
#  10  Date          1447 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 124.7+ KB

# %% [markdown]
# 2) В этом задании мы поменяем тип переменной с object на datetime с помощью функции pd.to_datetime().

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].dtype
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 320 to 1449
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         182 non-null    object
#  1   Title        182 non-null    object
#  2   Director     182 non-null    object
#  3   Cast         182 non-null    object
#  4   Country      182 non-null    object
#  5   Rating       182 non-null    object
#  6   Duration     182 non-null    object
#  7   Listed_In    182 non-null    string
#  8   Description  182 non-null    object
#  9   Date         182 non-null    datetime64[ns]
#  10  Listed_In2   182 non-null    string
#  11  C            182 non-null    string
# dtypes: datetime64[ns](1), object(8), string(3)
# memory usage: 18.5+ KB
#        Type                                  Title  \
# 320   Movie                             700 Sharks
# 322   Movie         Dr. Seuss' Horton Hears a Who!
# ...

# %% [markdown]
# 3) Отфильтруйте все фильмы и сериалы, которые выходили с 1 января 2020 года по 1 января 2021 года. В результате выведите переменную с названиями десяти первых фильмов после фильтрации, с помощью функции head().

# %%
df = df[(df['Date'] >= '2020-01-01') & (df['Date'] <= '2021-01-01')]
df
# Out:
#          type                                  title  \
# 320     Movie                             700 Sharks
# 321     Movie                        Big Sharks Rule
# 322     Movie         Dr. Seuss' Horton Hears a Who!
# 323     Movie                  Great Shark Chow Down
# 324     Movie                        Mega Hammerhead
# ...       ...                                    ...
# 672   TV Show                   The Super Hero Squad
# 673   TV Show                           Year Million
# 1447    Movie                        Eddie the Eagle
# 1448    Movie                   Bend It Like Beckham
# 1449    Movie  Captain Sparky vs. The Flying Saucers
#
#                           director  \
# 320                   Luc Marescot
# 321                            NaN
# 322   Jimmy Hayward, Steve Martino
# 323                  Mark Woodward
# 324     Brandon Hill, Marc Ostrick
# ...                            ...
# 672                            NaN
# ...

# %% [markdown]
# 4) Вам необходимо удалить столбец из датасета 'release_year' и вывести название оставшихся столбцов с помощью функции list().

# %%
columns = list(df)
columns
# Out:
# ['type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'Date']

# %%
df = df.drop('release_year', axis=1)
columns = list(df)
columns
# Out:
# ['type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'Date']

# %% [markdown]
# 5) Необходимо поменять название переменных из 'disney_title.csv' на такие же названия написанные с большой буквы

# %%
columns = list(df)
columns
# Out:
# ['type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'Date']

# %%
newcolumns = [column.title() for column in columns]
newcolumns
# Out:
# ['Type',
#  'Title',
#  'Director',
#  'Cast',
#  'Country',
#  'Rating',
#  'Duration',
#  'Listed_In',
#  'Description',
#  'Date']

# %% [markdown]
# 6) В этом задании вам необходимо заменить "&" на "," в столбце "listed_in", сохранить результат в новую переменную вывести последнии пять значений в новой переменной с помощью функции 'tail()'

# %%
df['C'] = df['Listed_In'].astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 320 to 1449
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         357 non-null    object
#  1   Title        357 non-null    object
#  2   Director     209 non-null    object
#  3   Cast         311 non-null    object
#  4   Country      313 non-null    object
#  5   Rating       357 non-null    object
#  6   Duration     357 non-null    object
#  7   Listed_In    357 non-null    string
#  8   Description  357 non-null    object
#  9   Date         357 non-null    datetime64[ns]
#  10  Listed_In2   357 non-null    string
#  11  C            357 non-null    string
# dtypes: datetime64[ns](1), object(8), string(3)
# memory usage: 36.3+ KB
#          Type                                  Title  \
# 320     Movie                             700 Sharks
# 321     Movie                        Big Sharks Rule
# ...

# %%
df['Listed_In']= df['Listed_In'].str.replace('&',',')
df['Listed_In'].tail()
# Out:
# 672               Action-Adventure, Animation, Comedy
# 673                       Docuseries, Science Fiction
# 1447                      Biographical, Comedy, Drama
# 1448                     Buddy, Comedy, Coming of Age
# 1449    Action-Adventure, Animals , Nature, Animation
# Name: Listed_In, dtype: string

# %% [markdown]
# 7) В этой задаче требуется вывести количество пропущенных значений по каждому стобцу.

# %%
print(df.isnull().sum())
print(df.isnull().mean()*100)

# %% [markdown]
# 8) В этом задании заменить пропущенные значения в стобце 'country' на 'Country not specified' с помощью функции 'fillna'.

# %%
df['Country'] = df['Country'].fillna('Country not specified')
print(df['Country'].head(5))
# Out:
# 320           France
# 322    United States
# 324    United States
# 328    United States
# 329    United States
# Name: Country, dtype: object

# %%
df
# Out:
#        Type                                  Title  \
# 320   Movie                             700 Sharks
# 322   Movie         Dr. Seuss' Horton Hears a Who!
# 324   Movie                        Mega Hammerhead
# 328   Movie                  Max Keeble's Big Move
# 329   Movie                                   Soul
# ...     ...                                    ...
# 666   Movie     Marvel 75 Years: From Pulp to Pop!
# 670   Movie                            Super Rhino
# 1447  Movie                        Eddie the Eagle
# 1448  Movie                   Bend It Like Beckham
# 1449  Movie  Captain Sparky vs. The Flying Saucers
#
#                           Director  \
# 320                   Luc Marescot
# 322   Jimmy Hayward, Steve Martino
# 324     Brandon Hill, Marc Ostrick
# 328                       Tim Hill
# 329                    Pete Docter
# ...                            ...
# 666                    Zak Knutson
# 670                   Nathan Greno
# ...
